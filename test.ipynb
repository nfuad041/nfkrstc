# %%
import pandas as pd

# %%
fileDB = pd.read_hdf('/global/cfs/cdirs/legend/software/KrSTC/data/fileDB.h5')
pd.set_option("display.max_columns", None)
print(fileDB.columns)
fileDB
# Out:
# Index(['YYYY', 'cycle', 'daq_dir', 'daq_file', 'dd', 'detector', 'mm', 'run',
#        'runtype', 'skip', 'unique_key', 'raw_file', 'raw_path', 'dsp_file',
#        'dsp_path', 'hit_file', 'hit_path', 'startTime', 'threshold', 'daq_gb'],
#       dtype='object')
#      YYYY  cycle        daq_dir                     daq_file  dd detector  mm  \
# 0    2020   2019  /2020/06/Data  2020-6-11-BackgroundRun2019  11     oppi   6
# 1    2020   2020  /2020/06/Data  2020-6-11-BackgroundRun2020  11     oppi   6
# 2    2020   2021  /2020/06/Data  2020-6-11-BackgroundRun2021  11     oppi   6
# 3    2020   2022  /2020/06/Data  2020-6-11-BackgroundRun2022  11     oppi   6
# 4    2020   2023  /2020/06/Data  2020-6-11-BackgroundRun2023  11     oppi   6
# ..    ...    ...            ...                          ...  ..      ...  ..
# 337  2020   2356  /2020/06/Data  2020-6-28-BackgroundRun2356  28     oppi   6
# 338  2020   2357  /2020/06/Data  2020-6-28-BackgroundRun2357  28     oppi   6
# 339  2020   2358  /2020/06/Data  2020-6-28-BackgroundRun2358  28     oppi   6
# 340  2020   2359  /2020/06/Data  2020-6-28-BackgroundRun2359  28     oppi   6
# 341  2020   2360  /2020/06/Data  2020-6-28-BackgroundRun2360  28     oppi   6
#
#       run runtype   skip             unique_key                     raw_file  \
# 0     0.0     bkg  False  krstc-cyc2019-2020611   krstc_run0_cyc2019_raw.lh5
# 1     0.0     bkg  False  krstc-cyc2020-2020611   krstc_run0_cyc2020_raw.lh5
# 2     0.0     bkg  False  krstc-cyc2021-2020611   krstc_run0_cyc2021_raw.lh5
# 3     0.0     bkg  False  krstc-cyc2022-2020611   krstc_run0_cyc2022_raw.lh5
# 4     0.0     bkg  False  krstc-cyc2023-2020611   krstc_run0_cyc2023_raw.lh5
# ..    ...     ...    ...                    ...                          ...
# 337  20.0     bkg  False  krstc-cyc2356-2020628  krstc_run20_cyc2356_raw.lh5
# 338  20.0     bkg  False  krstc-cyc2357-2020628  krstc_run20_cyc2357_raw.lh5
# 339  20.0     bkg  False  krstc-cyc2358-2020628  krstc_run20_cyc2358_raw.lh5
# 340  20.0     bkg  False  krstc-cyc2359-2020628  krstc_run20_cyc2359_raw.lh5
# 341  20.0     bkg  False  krstc-cyc2360-2020628  krstc_run20_cyc2360_raw.lh5
#
#     raw_path                     dsp_file dsp_path  \
# 0       /raw   krstc_run0_cyc2019_dsp.lh5     /dsp
# 1       /raw   krstc_run0_cyc2020_dsp.lh5     /dsp
# 2       /raw   krstc_run0_cyc2021_dsp.lh5     /dsp
# 3       /raw   krstc_run0_cyc2022_dsp.lh5     /dsp
# 4       /raw   krstc_run0_cyc2023_dsp.lh5     /dsp
# ..       ...                          ...      ...
# 337     /raw  krstc_run20_cyc2356_dsp.lh5     /dsp
# 338     /raw  krstc_run20_cyc2357_dsp.lh5     /dsp
# 339     /raw  krstc_run20_cyc2358_dsp.lh5     /dsp
# 340     /raw  krstc_run20_cyc2359_dsp.lh5     /dsp
# 341     /raw  krstc_run20_cyc2360_dsp.lh5     /dsp
#
#                         hit_file hit_path     startTime  threshold    daq_gb
# 0     krstc_run0_cyc2019_hit.lh5     /hit  1.591914e+09      100.0  1.061043
# 1     krstc_run0_cyc2020_hit.lh5     /hit  1.591915e+09      100.0  2.002383
# 2     krstc_run0_cyc2021_hit.lh5     /hit  1.591917e+09      100.0  2.035477
# 3     krstc_run0_cyc2022_hit.lh5     /hit  1.591917e+09      100.0  2.058530
# 4     krstc_run0_cyc2023_hit.lh5     /hit  1.591917e+09      100.0  2.088009
# ..                           ...      ...           ...        ...       ...
# 337  krstc_run20_cyc2356_hit.lh5     /hit  1.593380e+09      100.0  1.483477
# 338  krstc_run20_cyc2357_hit.lh5     /hit  1.593381e+09      100.0  1.486155
# 339  krstc_run20_cyc2358_hit.lh5     /hit  1.593382e+09      100.0  1.479927
# 340  krstc_run20_cyc2359_hit.lh5     /hit  1.593383e+09      100.0  1.484824
# 341  krstc_run20_cyc2360_hit.lh5     /hit  1.593385e+09      100.0  1.099477
#
# [342 rows x 20 columns]
