# %% [markdown]
# Peaks that I think are most eligible for calibration|||||
# Isotope|True value|Value on data|diff|Event/bkg|event/bkg/diff
# |keV|keV|keV||
# 212Pb|239.6|239|0.599999999999994|2|3
# 214Pb|295.2|295.5|0.300000000000011|3|10
# 214Pb|351.9|352.2|0.300000000000011|6|20
# 208Tl|583.2|583|0.200000000000045|6|30
# 228Ac|911.2|911|0.200000000000045|7|35
# 214Bi|1120.3|1120|0.299999999999955|3|10
# 40K|1460.8|1460.8|0|15|#DIV/0!
# 214Bi|1764.5|1764.5|0|10|#DIV/0!
# |||||
# |||||
# Peaks that are not in the peak_list, but present in data (keV)|||||
# 273.5|||||
# 547|||||
# Double peak at 679 and 683.5|||||

# %% [markdown]
# ## Histogram of trapEmax (calibrated using $y=0.4495x + 0.2385$)

# %%
from pygama import DataGroup
import pygama.lh5 as lh5
import pygama.analysis.histograms as pgh
import pygama.utils as pgu
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle as pk


title_fontsize = 20
colors = ['b','g','r','c','y','m','k','maroon','dodgerblue','darkgoldenrod', 'gold',
         'darkslategray', 'orange']

# %%
isotopes = np.asarray(['212Pb', '214Pb', '214Pb', '208Tl', '228Ac', '214Bi', '40K', '214Bi'])
true_values = np.asarray([239.6,295.2, 351.9, 583.2, 911.2,1120.3,1460.8, 1764.5])
values_on_data = np.asarray([239,295.5,352.2,583,911,1120,1460.8, 1764.5])
diff = np.abs(true_values-value_on_data)
event_per_bkg = np.asarray([2,3,6,6,7,3,15,10])
event_per_bkg_per_diff = event_per_bkg/diff
usable_peaks_dict={'Isotopes':isotopes, 
                   'true_values (keV)':true_values,
                   'values on data (keV)':values_on_data,
                   'Diff (keV)':diff,
                   'event/bkg':event_per_bkg,
                   'event/bkg/diff':event_per_bkg_per_diff}
pd.DataFrame(usable_peaks_dict)
# Out:
# <ipython-input-25-3813b1650efb>:6: RuntimeWarning: divide by zero encountered in true_divide
#   event_per_bkg_per_diff = event_per_bkg/diff
#   Isotopes  true_values (keV)  values on data (keV)  Diff (keV)  event/bkg  \
# 0    212Pb              239.6                 239.0         0.6          2
# 1    214Pb              295.2                 295.5         0.3          3
# 2    214Pb              351.9                 352.2         0.3          6
# 3    208Tl              583.2                 583.0         0.2          6
# 4    228Ac              911.2                 911.0         0.2          7
# 5    214Bi             1120.3                1120.0         0.3          3
# 6      40K             1460.8                1460.8         0.0         15
# 7    214Bi             1764.5                1764.5         0.0         10
#
#    event/bkg/diff
# 0        3.333333
# 1       10.000000
# 2       20.000000
# 3       30.000000
# 4       35.000000
# 5       10.000000
# 6             inf
# 7             inf

# %%
energy_calibrated = pk.load(open('trapEmax_calibrated.pk','rb'))
peak_list = pd.read_csv('peak_list.txt', delimiter=' ')

n_bins = 1500
adc_range = (0,3000)
hist, bins, var = pgh.get_hist(energy_calibrated, bins = n_bins, 
                               range=adc_range)


peak_list_tall = peak_list[peak_list.iloc[:,2]=='T']
#peak_list_tall
#T=Tall means yes you might be able to calibrate with this
def print_a_range(x_min, x_max, tall_peaks=False, figsize=(24,16)):
    plt.figure(figsize=figsize)
    pgh.plot_hist(hist, bins, lw=2)
    color_index=0
    peak_list_to_plot = peak_list
    if tall_peaks: peak_list_to_plot = peak_list_tall
    color_index=0
    for i in range(peak_list_to_plot.shape[0]):
        label = ''
        if peak_list_to_plot.iloc[i,1]<x_max and peak_list_to_plot.iloc[i,1]>x_min:
            is_tall_label=''
            if peak_list_to_plot.iloc[i,2]=='T': is_tall_label=' T'
            label = peak_list_to_plot.iloc[i,0]+'='+str(peak_list_to_plot.iloc[i,1])+is_tall_label
        plt.axvline(x=peak_list_to_plot.iloc[i,1], label=label, 
                        color=colors[color_index%12], ls='--', lw=2)
        color_index+=1
    plt.legend(bbox_to_anchor=(1, 1), loc='upper left', ncol=1, fontsize=title_fontsize)
    plt.title('trapEmax calibrated', fontsize=title_fontsize)
    plt.yscale('log')
    plt.xlim(x_min,x_max)
    plt.xticks(fontsize=title_fontsize)
    plt.yticks(fontsize=title_fontsize)
    plt.xlabel('keV (bin size =~'+str(adc_range[1]/n_bins)+' keV)',fontsize=title_fontsize)
    plt.ylabel('# of events',fontsize=title_fontsize)
    plt.show()
print_a_range(0,2800)

# %%
start = 0
end = 2800
while start<=end:
    print_a_range(start, start+200, tall_peaks=False, figsize=(20,15))
    start=start+200
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
